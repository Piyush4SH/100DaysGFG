# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-cdf2287e0e4f> in <cell line: 1>()
# ----> 1 df=pd.read_csv('/content/drive/MyDrive/ML/Module_End/creditcard_2023.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df.shape
# Out:
# (568630, 31)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.head(100)
# Out:
#     id        V1        V2        V3        V4        V5        V6        V7  \
# 0    0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1    1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2    2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3    3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4    4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
# 5    5  0.025302 -0.140514  1.191138 -0.707979  0.430490  0.458973  0.611050
# 6    6  1.016482 -0.397181  0.497868 -0.144463  0.331022  0.629243  0.431262
# 7    7 -0.051306 -0.007194  1.139941 -0.877880  0.684668  0.714326  0.892615
# 8    8 -0.130680 -0.349547  0.425786 -0.760444  1.702777  2.324816  0.568968
# 9    9  0.058419 -0.093507  1.117270 -0.735172  0.466111  0.332371  0.683425
# 10  10  1.206014 -0.883519  1.021299 -1.410047 -0.341591  0.101491  0.036318
# ...

# %%
df.isnull().sum()
# Out:
# id        0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.dtypes
# Out:
# id          int64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568630 entries, 0 to 568629
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      568630 non-null  int64
#  1   V1      568630 non-null  float64
#  2   V2      568630 non-null  float64
#  3   V3      568630 non-null  float64
#  4   V4      568630 non-null  float64
#  5   V5      568630 non-null  float64
#  6   V6      568630 non-null  float64
#  7   V7      568630 non-null  float64
#  8   V8      568630 non-null  float64
#  9   V9      568630 non-null  float64
#  10  V10     568630 non-null  float64
#  11  V11     568630 non-null  float64
#  12  V12     568630 non-null  float64
#  13  V13     568630 non-null  float64
#  14  V14     568630 non-null  float64
#  15  V15     568630 non-null  float64
#  16  V16     568630 non-null  float64
#  17  V17     568630 non-null  float64
#  18  V18     568630 non-null  float64
#  19  V19     568630 non-null  float64
# ...

# %%
df.describe()
# Out:
#                   id            V1            V2            V3            V4  \
# count  568630.000000  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean   284314.500000 -5.638058e-17 -1.319545e-16 -3.518788e-17 -2.879008e-17
# std    164149.486122  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min         0.000000 -3.495584e+00 -4.996657e+01 -3.183760e+00 -4.951222e+00
# 25%    142157.250000 -5.652859e-01 -4.866777e-01 -6.492987e-01 -6.560203e-01
# 50%    284314.500000 -9.363846e-02 -1.358939e-01  3.528579e-04 -7.376152e-02
# 75%    426471.750000  8.326582e-01  3.435552e-01  6.285380e-01  7.070047e-01
# max    568629.000000  2.229046e+00  4.361865e+00  1.412583e+01  3.201536e+00
#
#                  V5            V6            V7            V8            V9  \
# count  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean   7.997245e-18 -3.958636e-17 -3.198898e-17  2.109273e-17  3.998623e-17
# ...

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 31)

# %%
df.Class.value_counts()
# Out:
# 0    284315
# 1    284315
# Name: Class, dtype: int64

# %%
df.Class.value_counts()*100/len(df)
# Out:
# 0    50.0
# 1    50.0
# Name: Class, dtype: float64

# %%
percentage_0 = (df['Class'] == 0).mean() * 100
percentage_1 = (df['Class'] == 1).mean() * 100

plt.bar(['Non_fradulent_0', 'Fradulent_1'], [percentage_0, percentage_1], color=['blue', 'red'])
plt.xlabel('Class')
plt.ylabel('Percentage')
plt.title('Percentage of 0s and 1s in Class Column')
# Out:
# Text(0.5, 1.0, 'Percentage of 0s and 1s in Class Column')

# %% [markdown]
# observations
#
# 1)We have 568630 rows of obervations having 31 columns
#
# 2)'Class' is target feature indicating whether the transaction is "Fraudulent" (1) or "Not Fraudulent" (0)
#
# 3)"V1-V28" anonymized features representing various transaction attributes.
#
# 4)Data types of all the features looks perfects
#
# 5)Dataset is balanced as count of fraudulent and not fraudulent is equal
#
# 6)No null values found in the dataset

# %%
# Observing the Disribution of the Feature 'Class'
colors = ['red', 'blue']
explode = [0.1, 0]
df['Class'].value_counts().plot.pie(
    explode=explode,
    autopct='%3.1f%%',
    shadow=True,
    legend=True,
    startangle=45,
    colors=colors,
    wedgeprops=dict(width=0.4)
)

plt.title('Distribution of Class',size=14)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4c8b2fcffe81> in <cell line: 4>()
#       2 colors = ['red', 'blue']
#       3 explode = [0.1, 0]
# ----> 4 df['Class'].value_counts().plot.pie(
#       5     explode=explode,
#       6     autopct='%3.1f%%',
#
# NameError: name 'df' is not defined

# %%
corr_matrix = df.corr()
print(corr_matrix["Class"].sort_values(ascending=False))
# Out:
# Class     1.000000
# id        0.864283
# V4        0.735981
# V11       0.724278
# V2        0.491878
# V19       0.244081
# V27       0.214002
# V20       0.179851
# V8        0.144294
# V21       0.109640
# V28       0.102024
# V26       0.071052
# V25       0.061847
# V22       0.014098
# V23       0.010255
# Amount    0.002261
# V15      -0.037948
# V13      -0.071105
# V24      -0.130107
# V5       -0.338639
# V18      -0.410091
# V6       -0.435088
# V17      -0.476377
# V7       -0.491234
# V1       -0.505761
# V16      -0.573511
# V9       -0.585522
# V10      -0.673665
# V3       -0.682095
# V12      -0.768579
# V14      -0.805669
# Name: Class, dtype: float64

# %%
ab_corr_matrix=corr_matrix.abs()
ab_corr_matrix
# Out:
#               id        V1        V2        V3        V4        V5        V6  \
# id      1.000000  0.395741  0.424267  0.663655  0.617554  0.268445  0.387916
# V1      0.395741  1.000000  0.561184  0.484499  0.498963  0.517462  0.354728
# V2      0.424267  0.561184  1.000000  0.627810  0.579638  0.631669  0.341040
# V3      0.663655  0.484499  0.627810  1.000000  0.687726  0.510351  0.508974
# V4      0.617554  0.498963  0.579638  0.687726  1.000000  0.429243  0.474403
# V5      0.268445  0.517462  0.631669  0.510351  0.429243  1.000000  0.245187
# V6      0.387916  0.354728  0.341040  0.508974  0.474403  0.245187  1.000000
# V7      0.414288  0.573381  0.694022  0.634336  0.588648  0.586828  0.418703
# V8      0.121282  0.226757  0.191321  0.263018  0.199013  0.314975  0.604491
# V9      0.508427  0.548973  0.585095  0.648615  0.676648  0.479614  0.432241
# V10     0.578014  0.599108  0.621798  0.707676  0.712839  0.563874  0.471000
# ...

# %%
plt.figure(figsize=(50,50))
plt.show(sns.heatmap(df.corr(), cmap='RdYlGn', annot=True))

# %%
x1=ab_corr_matrix[ab_corr_matrix['Class']>0.5].index
x1
# Out:
# Index(['id', 'V1', 'V3', 'V4', 'V9', 'V10', 'V11', 'V12', 'V14', 'V16',
#        'Class'],
#       dtype='object')

# %%
x = df[['V1', 'V3', 'V4', 'V9', 'V10', 'V11', 'V12', 'V14', 'V16']]
y = df['Class']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = scaler.fit_transform(x)
print(x)
# Out:
# [[-0.2606478   2.49626608 -0.08372391 ...  0.2934381   0.54901989
#    0.21559799]
#  [ 0.98509973  0.55805635 -0.4296539  ...  1.56424577  0.62771874
#    0.78918836]
#  [-0.26027161  1.72853778 -0.45798629 ...  0.65920066  0.61687439
#   -0.57751352]
#  ...
#  [-0.31199739  0.13752559 -0.03589304 ... -0.46184889 -0.3951258
#   -0.37020112]
#  [ 0.63687054 -0.30088853 -0.14447996 ...  0.33521507 -0.39036945
#    0.47740224]
#  [-0.79514417 -0.64914005  0.37473206 ... -1.1530113  -1.06248832
#   -0.91723954]]

# %% [markdown]
# **Splitting**

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %% [markdown]
# **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_rf=rf.predict(x_test)

# %%
print("Randon Forest Classifier")
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_rf))
print("\nClassification Report:\n", classification_report(y_test, y_pred_rf))
print("\nAccuracy Score:", accuracy_score(y_test, y_pred_rf)*100,"%")
# Out:
# Randon Forest Classifier
# Confusion Matrix:
#  [[56687    37]
#  [    5 56997]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56724
#            1       1.00      1.00      1.00     57002
#
#     accuracy                           1.00    113726
#    macro avg       1.00      1.00      1.00    113726
# weighted avg       1.00      1.00      1.00    113726
#
#
# Accuracy Score: 99.96306913106942 %

# %% [markdown]
# **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred_reg =  lr.predict(x_test)

# %%
print("Logistic Regression Model")
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_reg))
print("\nClassification Report:\n", classification_report(y_test, y_pred_reg))
print("\nAccuracy Score:", accuracy_score(y_test, y_pred_reg)*100,"%")
# Out:
# Logistic Regression Model
# Confusion Matrix:
#  [[55457  1267]
#  [ 3549 53453]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96     56724
#            1       0.98      0.94      0.96     57002
#
#     accuracy                           0.96    113726
#    macro avg       0.96      0.96      0.96    113726
# weighted avg       0.96      0.96      0.96    113726
#
#
# Accuracy Score: 95.76526036262595 %

# %% [markdown]
# **Support Vector Machine**

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_pred_svm = svc.predict(x_test)

# %%
print("Support Vector Machine")
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_svm))
print("\nClassification Report:\n", classification_report(y_test, y_pred_svm))
print("\nAccuracy Score:", accuracy_score(y_test, y_pred_svm)*100,"%")
# Out:
# Support Vector Machine
# Confusion Matrix:
#  [[55723  1001]
#  [ 1476 55526]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     56724
#            1       0.98      0.97      0.98     57002
#
#     accuracy                           0.98    113726
#    macro avg       0.98      0.98      0.98    113726
# weighted avg       0.98      0.98      0.98    113726
#
#
# Accuracy Score: 97.82195803949844 %

# %% [markdown]
# **Deep Learning**
# 1. ANN

# %%
x= df.iloc[:, :-1].values
y=df.iloc[:,-1].values

# %%
x
# Out:
# array([[ 0.00000000e+00, -2.60647805e-01, -4.69648450e-01, ...,
#         -8.12301086e-02, -1.51045486e-01,  1.79821000e+04],
#        [ 1.00000000e+00,  9.85099734e-01, -3.56045093e-01, ...,
#         -2.48052059e-01, -6.45119230e-02,  6.53137000e+03],
#        [ 2.00000000e+00, -2.60271613e-01, -9.49384607e-01, ...,
#         -3.00258035e-01, -2.44718229e-01,  2.51354000e+03],
#        ...,
#        [ 5.68627000e+05, -3.11997393e-01, -4.09479480e-03, ...,
#         -4.87539751e-01, -2.68741268e-01,  2.35728500e+04],
#        [ 5.68628000e+05,  6.36870539e-01, -5.16969517e-01, ...,
#         -1.59269263e-01, -7.62505739e-02,  1.01608300e+04],
#        [ 5.68629000e+05, -7.95144165e-01,  4.33236084e-01, ...,
#         -1.57511260e+00,  7.22936496e-01,  2.14939200e+04]])

# %%
y
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %% [markdown]
# **Splitting**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
#Feature scaling
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
#Initializing the ANN
import tensorflow as tf
ann=tf.keras.models.Sequential()

# %%
from keras import layers
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
#adding input layer
ann.add(Dense(units=164, activation='relu'))

# %%
#adding second hidden line
ann.add(Dense(units=64, activation='relu'))

# %%
ann.add(Dense(units=28, activation='relu'))

# %%
#adding an output layer
ann.add(Dense(units=1, activation='sigmoid'))

# %%
ann.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])

# %%
#fitting
ann.fit(x_train,y_train,batch_size=1000,epochs=3)
# Out:
# Epoch 1/3
# 455/455 [==============================] - 4s 6ms/step - loss: 0.0325 - accuracy: 0.9890
# Epoch 2/3
# 455/455 [==============================] - 2s 5ms/step - loss: 0.0031 - accuracy: 0.9993
# Epoch 3/3
# 455/455 [==============================] - 2s 5ms/step - loss: 0.0023 - accuracy: 0.9995

# %%
#prediction
y_pred=ann.predict(x_test)
# Out:
# 3554/3554 [==============================] - 9s 2ms/step

# %%
y_pred
# Out:
# array([[1.0000000e+00],
#        [1.0000000e+00],
#        [1.0000000e+00],
#        ...,
#        [1.1293724e-03],
#        [2.2264179e-05],
#        [1.0000000e+00]], dtype=float32)

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# Assuming y_pred contains continuous values
threshold = 0.5
y_pred_binary = (y_pred > threshold).astype(int)

# Now you can use the classification metrics with y_test and y_pred_binary
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_binary))
print("\nClassification Report:\n", classification_report(y_test, y_pred_binary))
print("\nAccuracy Score:", accuracy_score(y_test, y_pred_binary) * 100, "%")
# Out:
# Confusion Matrix:
#  [[56696    28]
#  [   16 56986]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56724
#            1       1.00      1.00      1.00     57002
#
#     accuracy                           1.00    113726
#    macro avg       1.00      1.00      1.00    113726
# weighted avg       1.00      1.00      1.00    113726
#
#
# Accuracy Score: 99.96131051826319 %

# %% [markdown]
# RNN

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import LSTM, Dense

# %%
import tensorflow as tf
from tensorflow import keras

# Assuming your input is a sequence of 30 timesteps, each with one feature.
lstm = keras.Sequential([
    keras.layers.LSTM(50, input_shape=(30, 1), return_sequences=True),
    keras.layers.LSTM(25),
    keras.layers.Dense(1, activation='sigmoid')
])

lstm.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

lstm.fit(x_train, y_train, epochs=10, batch_size=1000)
# Out:
# Epoch 1/10
# 455/455 [==============================] - 111s 230ms/step - loss: 0.1380 - accuracy: 0.9511
# Epoch 2/10
# 455/455 [==============================] - 104s 228ms/step - loss: 0.0216 - accuracy: 0.9928
# Epoch 3/10
# 455/455 [==============================] - 102s 225ms/step - loss: 0.0117 - accuracy: 0.9963
# Epoch 4/10
# 455/455 [==============================] - 103s 226ms/step - loss: 0.0086 - accuracy: 0.9975
# Epoch 5/10
# 455/455 [==============================] - 102s 225ms/step - loss: 0.0076 - accuracy: 0.9979
# Epoch 6/10
# 455/455 [==============================] - 101s 223ms/step - loss: 0.0061 - accuracy: 0.9985
# Epoch 7/10
# 455/455 [==============================] - 118s 259ms/step - loss: 0.0057 - accuracy: 0.9986
# Epoch 8/10
# 455/455 [==============================] - 104s 229ms/step - loss: 0.0058 - accuracy: 0.9986
# Epoch 9/10
# 455/455 [==============================] - 100s 221ms/step - loss: 0.0057 - accuracy: 0.9986
# Epoch 10/10
# ...

# %%
corr_matrix = df.corr()

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# Assuming y_pred contains continuous values
threshold = 0.5
y_pred_binary = (y_pred > threshold).astype(int)

# Now you can use the classification metrics with y_test and y_pred_binary
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_binary))
print("\nClassification Report:\n", classification_report(y_test, y_pred_binary))
print("\nAccuracy Score:", accuracy_score(y_test, y_pred_binary) * 100, "%")
# Out:
# Confusion Matrix:
#  [[56699    25]
#  [   19 56983]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56724
#            1       1.00      1.00      1.00     57002
#
#     accuracy                           1.00    113726
#    macro avg       1.00      1.00      1.00    113726
# weighted avg       1.00      1.00      1.00    113726
#
#
# Accuracy Score: 99.96131051826319 %

# %% [markdown]
# **Conclusion**
# **Data Exploration:**
# 1. The page shows how to load, inspect, and preprocess a
#    dataset of credit card transactions from 2023, with the goal of detecting fraudulent transactions.
# 2. The dataset has 568,630 rows and 31 columns, with no
#    missing values or duplicates. The target variable is ‘Class’, which indicates whether the transaction is fraudulent (1) or not (0).The dataset is balanced, with 50% of each class.

# %% [markdown]
# 1. The performance of the models on the test set, and finds
#    that the artificial neural network and the recurrent neural network have the highest accuracy of 99.96%, followed by the random forest with 99.96%, the support vector machine with 97.82%, and the logistic regression with 95.77%.
# 2. So conclusion is that the deep learning models are more
#    effective than the machine learning models for this task.
#
# **Conclusion based on dataset and output of algorithm:**
# 1. Using most effective deep learning ann and rnn             algorithm, we can predict accurate result for 99 client for
#    every 100 clients that weather he/she has done fraudulent credit card transaction or not
